# %%
# OCR 모델
# !pip install easyocr==1.7.1
# 이미지 영상 처리
# !pip install opencv-python
# PyTorch와 torchvision 설치
# !pip install torch==2.2.1
# !pip install torchvision==0.17.1
# !pip install torchaudio==2.2.1
# matplotlib 설치
# !pip install matplotlib
# GUI 없는 환경에서 OpenCV 사용을 위해
# !pip install opencv-python-headless
# spellchecker 설치
# !pip install pyspellchecker
# wordninja 설치
# !pip install wordninja
# 한국어 맞춤법 교정기
# !pip install py-hanspell
# Out:
# Requirement already satisfied: easyocr==1.7.1 in c:\users\peter\appdata\roaming\python\python312\site-packages (1.7.1)
# Requirement already satisfied: torch in c:\users\peter\appdata\roaming\python\python312\site-packages (from easyocr==1.7.1) (2.2.1)
# Requirement already satisfied: torchvision>=0.5 in c:\users\peter\appdata\roaming\python\python312\site-packages (from easyocr==1.7.1) (0.17.1)
# Requirement already satisfied: opencv-python-headless in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from easyocr==1.7.1) (4.8.0.74)
# Requirement already satisfied: scipy in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from easyocr==1.7.1) (1.12.0)
# Requirement already satisfied: numpy in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from easyocr==1.7.1) (1.26.4)
# Requirement already satisfied: Pillow in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from easyocr==1.7.1) (10.3.0)
# Requirement already satisfied: scikit-image in c:\users\peter\appdata\roaming\python\python312\site-packages (from easyocr==1.7.1) (0.22.0)
# Requirement already satisfied: python-bidi in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from easyocr==1.7.1) (0.4.2)
# Requirement already satisfied: PyYAML in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from easyocr==1.7.1) (6.0.1)
# Requirement already satisfied: Shapely in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from easyocr==1.7.1) (2.0.3)
# Requirement already satisfied: pyclipper in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from easyocr==1.7.1) (1.3.0.post5)
# Requirement already satisfied: ninja in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from easyocr==1.7.1) (1.11.1.1)
# Requirement already satisfied: filelock in c:\users\peter\appdata\roaming\python\python312\site-packages (from torch->easyocr==1.7.1) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from torch->easyocr==1.7.1) (4.9.0)
# Requirement already satisfied: sympy in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from torch->easyocr==1.7.1) (1.12)
# Requirement already satisfied: networkx in c:\users\peter\appdata\roaming\python\python312\site-packages (from torch->easyocr==1.7.1) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from torch->easyocr==1.7.1) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\peter\appdata\roaming\python\python312\site-packages (from torch->easyocr==1.7.1) (2024.3.1)
# Requirement already satisfied: six in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from python-bidi->easyocr==1.7.1) (1.16.0)
# Requirement already satisfied: imageio>=2.27 in c:\users\peter\appdata\roaming\python\python312\site-packages (from scikit-image->easyocr==1.7.1) (2.34.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from scikit-image->easyocr==1.7.1) (2024.2.12)
# Requirement already satisfied: packaging>=21 in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from scikit-image->easyocr==1.7.1) (23.2)
# Requirement already satisfied: lazy_loader>=0.3 in c:\users\peter\appdata\roaming\python\python312\site-packages (from scikit-image->easyocr==1.7.1) (0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from jinja2->torch->easyocr==1.7.1) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from sympy->torch->easyocr==1.7.1) (1.3.0)
# Requirement already satisfied: opencv-python in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from opencv-python) (1.26.4)
# Collecting torch==2.2.0
#   Downloading torch-2.2.0-cp312-cp312-win_amd64.whl.metadata (26 kB)
# Requirement already satisfied: filelock in c:\users\peter\appdata\roaming\python\python312\site-packages (from torch==2.2.0) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from torch==2.2.0) (4.9.0)
# Requirement already satisfied: sympy in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from torch==2.2.0) (1.12)
# Requirement already satisfied: networkx in c:\users\peter\appdata\roaming\python\python312\site-packages (from torch==2.2.0) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from torch==2.2.0) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\peter\appdata\roaming\python\python312\site-packages (from torch==2.2.0) (2024.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from jinja2->torch==2.2.0) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from sympy->torch==2.2.0) (1.3.0)
# Downloading torch-2.2.0-cp312-cp312-win_amd64.whl (198.5 MB)
#    ---------------------------------------- 0.0/198.5 MB ? eta -:--:--
#    ---------------------------------------- 0.9/198.5 MB 18.5 MB/s eta 0:00:11
#    ---------------------------------------- 1.0/198.5 MB 16.4 MB/s eta 0:00:13
#    ---------------------------------------- 1.0/198.5 MB 16.4 MB/s eta 0:00:13
#    ---------------------------------------- 1.0/198.5 MB 16.4 MB/s eta 0:00:13
#    ---------------------------------------- 1.0/198.5 MB 16.4 MB/s eta 0:00:13
#    ---------------------------------------- 1.0/198.5 MB 16.4 MB/s eta 0:00:13
#    ---------------------------------------- 1.0/198.5 MB 16.4 MB/s eta 0:00:13
#    ---------------------------------------- 1.6/198.5 MB 4.6 MB/s eta 0:00:43
#     --------------------------------------- 2.8/198.5 MB 7.2 MB/s eta 0:00:28
#     --------------------------------------- 3.7/198.5 MB 8.4 MB/s eta 0:00:24
#     --------------------------------------- 4.6/198.5 MB 9.5 MB/s eta 0:00:21
#    - -------------------------------------- 5.8/198.5 MB 10.9 MB/s eta 0:00:18
#    - -------------------------------------- 6.8/198.5 MB 11.8 MB/s eta 0:00:17
#    - -------------------------------------- 8.5/198.5 MB 14.0 MB/s eta 0:00:14
#    - -------------------------------------- 9.7/198.5 MB 14.7 MB/s eta 0:00:13
#    -- ------------------------------------- 11.2/198.5 MB 16.0 MB/s eta 0:00:12
#    -- ------------------------------------- 12.5/198.5 MB 26.2 MB/s eta 0:00:08
#    -- ------------------------------------- 14.0/198.5 MB 28.5 MB/s eta 0:00:07
#    --- ------------------------------------ 15.7/198.5 MB 29.7 MB/s eta 0:00:07
#    --- ------------------------------------ 17.0/198.5 MB 31.2 MB/s eta 0:00:06
#    --- ------------------------------------ 18.4/198.5 MB 29.8 MB/s eta 0:00:07
#    --- ------------------------------------ 19.4/198.5 MB 28.5 MB/s eta 0:00:07
#    ---- ----------------------------------- 21.3/198.5 MB 29.7 MB/s eta 0:00:06
#    ---- ----------------------------------- 22.4/198.5 MB 29.7 MB/s eta 0:00:06
#    ---- ----------------------------------- 23.6/198.5 MB 29.7 MB/s eta 0:00:06
#    ----- ---------------------------------- 25.0/198.5 MB 29.7 MB/s eta 0:00:06
#    ----- ---------------------------------- 26.2/198.5 MB 31.2 MB/s eta 0:00:06
#    ----- ---------------------------------- 26.2/198.5 MB 31.2 MB/s eta 0:00:06
#    ----- ---------------------------------- 26.3/198.5 MB 24.2 MB/s eta 0:00:08
#    ----- ---------------------------------- 26.3/198.5 MB 21.1 MB/s eta 0:00:09
#    ----- ---------------------------------- 26.4/198.5 MB 19.3 MB/s eta 0:00:09
#    ----- ---------------------------------- 26.5/198.5 MB 18.2 MB/s eta 0:00:10
#    ----- ---------------------------------- 26.5/198.5 MB 16.8 MB/s eta 0:00:11
#    ----- ---------------------------------- 26.7/198.5 MB 15.2 MB/s eta 0:00:12
#    ----- ---------------------------------- 26.8/198.5 MB 14.6 MB/s eta 0:00:12
#    ----- ---------------------------------- 27.2/198.5 MB 13.6 MB/s eta 0:00:13
#    ----- ---------------------------------- 27.8/198.5 MB 13.4 MB/s eta 0:00:13
#    ----- ---------------------------------- 28.6/198.5 MB 12.6 MB/s eta 0:00:14
#    ------ --------------------------------- 29.8/198.5 MB 12.8 MB/s eta 0:00:14
#    ------ --------------------------------- 30.9/198.5 MB 12.3 MB/s eta 0:00:14
#    ------ --------------------------------- 32.0/198.5 MB 12.4 MB/s eta 0:00:14
#    ------ --------------------------------- 32.9/198.5 MB 11.9 MB/s eta 0:00:14
#    ------ --------------------------------- 33.5/198.5 MB 11.5 MB/s eta 0:00:15
#    ------ --------------------------------- 34.6/198.5 MB 11.1 MB/s eta 0:00:15
#    ------- -------------------------------- 35.5/198.5 MB 10.7 MB/s eta 0:00:16
#    ------- -------------------------------- 37.0/198.5 MB 16.8 MB/s eta 0:00:10
#    ------- -------------------------------- 38.5/198.5 MB 19.9 MB/s eta 0:00:09
#    -------- ------------------------------- 39.7/198.5 MB 21.1 MB/s eta 0:00:08
#    -------- ------------------------------- 41.0/198.5 MB 21.1 MB/s eta 0:00:08
#    -------- ------------------------------- 42.3/198.5 MB 22.6 MB/s eta 0:00:07
#    -------- ------------------------------- 43.8/198.5 MB 26.2 MB/s eta 0:00:06
#    --------- ------------------------------ 45.0/198.5 MB 27.3 MB/s eta 0:00:06
#    --------- ------------------------------ 46.0/198.5 MB 28.4 MB/s eta 0:00:06
#    --------- ------------------------------ 47.5/198.5 MB 31.2 MB/s eta 0:00:05
#    --------- ------------------------------ 49.3/198.5 MB 29.7 MB/s eta 0:00:06
#    ---------- ----------------------------- 50.8/198.5 MB 32.7 MB/s eta 0:00:05
#    ---------- ----------------------------- 52.2/198.5 MB 32.7 MB/s eta 0:00:05
#    ---------- ----------------------------- 53.5/198.5 MB 32.7 MB/s eta 0:00:05
#    ----------- ---------------------------- 55.2/198.5 MB 32.8 MB/s eta 0:00:05
#    ----------- ---------------------------- 56.6/198.5 MB 34.4 MB/s eta 0:00:05
#    ----------- ---------------------------- 58.3/198.5 MB 36.3 MB/s eta 0:00:04
#    ------------ --------------------------- 59.8/198.5 MB 34.6 MB/s eta 0:00:05
#    ------------ --------------------------- 61.4/198.5 MB 34.4 MB/s eta 0:00:04
#    ------------ --------------------------- 63.0/198.5 MB 36.3 MB/s eta 0:00:04
#    ------------ --------------------------- 64.5/198.5 MB 36.4 MB/s eta 0:00:04
#    ------------- -------------------------- 66.3/198.5 MB 38.6 MB/s eta 0:00:04
#    ------------- -------------------------- 67.9/198.5 MB 36.4 MB/s eta 0:00:04
#    ------------- -------------------------- 68.2/198.5 MB 36.4 MB/s eta 0:00:04
#    ------------- -------------------------- 68.2/198.5 MB 36.4 MB/s eta 0:00:04
#    ------------- -------------------------- 68.2/198.5 MB 36.4 MB/s eta 0:00:04
#    ------------- -------------------------- 68.2/198.5 MB 36.4 MB/s eta 0:00:04
#    ------------- -------------------------- 68.2/198.5 MB 36.4 MB/s eta 0:00:04
#    ------------- -------------------------- 68.6/198.5 MB 18.7 MB/s eta 0:00:07
#    -------------- ------------------------- 69.6/198.5 MB 17.7 MB/s eta 0:00:08
#    -------------- ------------------------- 70.6/198.5 MB 17.2 MB/s eta 0:00:08
#    -------------- ------------------------- 72.0/198.5 MB 16.8 MB/s eta 0:00:08
#    -------------- ------------------------- 73.1/198.5 MB 16.0 MB/s eta 0:00:08
#    --------------- ------------------------ 74.5/198.5 MB 16.0 MB/s eta 0:00:08
#    --------------- ------------------------ 75.5/198.5 MB 16.0 MB/s eta 0:00:08
#    --------------- ------------------------ 75.5/198.5 MB 16.0 MB/s eta 0:00:08
#    --------------- ------------------------ 75.7/198.5 MB 13.6 MB/s eta 0:00:10
#    --------------- ------------------------ 76.6/198.5 MB 13.6 MB/s eta 0:00:09
#    --------------- ------------------------ 77.8/198.5 MB 13.1 MB/s eta 0:00:10
#    --------------- ------------------------ 78.7/198.5 MB 19.2 MB/s eta 0:00:07
#    ---------------- ----------------------- 79.9/198.5 MB 20.5 MB/s eta 0:00:06
#    ---------------- ----------------------- 80.6/198.5 MB 19.9 MB/s eta 0:00:06
#    ---------------- ----------------------- 82.1/198.5 MB 19.3 MB/s eta 0:00:07
#    ---------------- ----------------------- 83.1/198.5 MB 19.3 MB/s eta 0:00:06
#    ---------------- -----------------------
2 MB/s eta 0:00:06
#    ---------------------- ---------------- 116.6/198.5 MB 16.0 MB/s eta 0:00:06
#    ----------------------- --------------- 117.7/198.5 MB 16.4 MB/s eta 0:00:05
#    ----------------------- --------------- 118.5/198.5 MB 16.4 MB/s eta 0:00:05
#    ----------------------- --------------- 118.5/198.5 MB 16.4 MB/s eta 0:00:05
#    ----------------------- --------------- 119.7/198.5 MB 14.9 MB/s eta 0:00:06
#    ----------------------- --------------- 120.4/198.5 MB 16.0 MB/s eta 0:00:05
#    ----------------------- --------------- 121.6/198.5 MB 16.0 MB/s eta 0:00:05
#    ------------------------ -------------- 122.4/198.5 MB 16.0 MB/s eta 0:00:05
#    ------------------------ -------------- 123.4/198.5 MB 16.4 MB/s eta 0:00:05
#    ------------------------ -------------- 124.5/198.5 MB 16.0 MB/s eta 0:00:05
#    ------------------------ -------------- 125.4/198.5 MB 18.2 MB/s eta 0:00:05
#    ------------------------ -------------- 125.7/198.5 MB 18.7 MB/s eta 0:00:04
#    ------------------------ -------------- 125.9/198.5 MB 16.8 MB/s eta 0:00:05
#    ------------------------- ------------- 127.3/198.5 MB 16.4 MB/s eta 0:00:05
#    ------------------------- ------------- 128.0/198.5 MB 17.2 MB/s eta 0:00:05
#    ------------------------- ------------- 129.0/198.5 MB 18.2 MB/s eta 0:00:04
#    ------------------------- ------------- 129.0/198.5 MB 18.2 MB/s eta 0:00:04
#    ------------------------- ------------- 129.0/198.5 MB 18.2 MB/s eta 0:00:04
#    ------------------------- ------------- 129.0/198.5 MB 18.2 MB/s eta 0:00:04
#    ------------------------- ------------- 129.3/198.5 MB 14.2 MB/s eta 0:00:05
#    ------------------------- ------------- 130.5/198.5 MB 14.6 MB/s eta 0:00:05
#    ------------------------- ------------- 131.7/198.5 MB 14.6 MB/s eta 0:00:05
#    -------------------------- ------------ 132.8/198.5 MB 14.6 MB/s eta 0:00:05
#    -------------------------- ------------ 134.0/198.5 MB 14.9 MB/s eta 0:00:05
#    -------------------------- ------------ 135.1/198.5 MB 14.9 MB/s eta 0:00:05
#    -------------------------- ------------ 135.3/198.5 MB 14.9 MB/s eta 0:00:05
#    -------------------------- ------------ 135.3/198.5 MB 14.9 MB/s eta 0:00:05
#    -------------------------- ------------ 135.4/198.5 MB 12.6 MB/s eta 0:00:06
#    -------------------------- ------------ 136.5/198.5 MB 13.6 MB/s eta 0:00:05
#    -------------------------- ------------ 137.3/198.5 MB 13.4 MB/s eta 0:00:05
#    --------------------------- ----------- 138.7/198.5 MB 13.9 MB/s eta 0:00:05
#    --------------------------- ----------- 139.8/198.5 MB 17.7 MB/s eta 0:00:04
#    --------------------------- ----------- 140.5/198.5 MB 17.2 MB/s eta 0:00:04
#    --------------------------- ----------- 141.5/198.5 MB 16.8 MB/s eta 0:00:04
#    --------------------------- ----------- 142.5/198.5 MB 16.8 MB/s eta 0:00:04
#    ---------------------------- ---------- 143.3/198.5 MB 16.8 MB/s eta 0:00:04
#    ---------------------------- ---------- 144.4/198.5 MB 16.8 MB/s eta 0:00:04
#    ---------------------------- ---------- 145.4/198.5 MB 16.8 MB/s eta 0:00:04
#    ---------------------------- ---------- 146.3/198.5 MB 20.5 MB/s eta 0:00:03
#    ---------------------------- ---------- 146.9/198.5 MB 19.8 MB/s eta 0:00:03
#    ---------------------------- ---------- 147.3/198.5 MB 18.2 MB/s eta 0:00:03
#    ----------------------------- --------- 148.4/198.5 MB 18.2 MB/s eta 0:00:03
#    ----------------------------- --------- 149.1/198.5 MB 17.7 MB/s eta 0:00:03
#    ----------------------------- --------- 149.3/198.5 MB 16.4 MB/s eta 0:00:04
MB 28.5 MB/s eta 0:00:01
#    ---------------------------------- ---- 177.2/198.5 MB 28.5 MB/s eta 0:00:01
#    ----------------------------------- --- 178.8/198.5 MB 29.7 MB/s eta 0:00:01
#    ----------------------------------- --- 180.0/198.5 MB 28.5 MB/s eta 0:00:01
#    ----------------------------------- --- 181.4/198.5 MB 29.7 MB/s eta 0:00:01
#    ----------------------------------- --- 181.4/198.5 MB 29.7 MB/s eta 0:00:01
#    ----------------------------------- --- 181.4/198.5 MB 29.7 MB/s eta 0:00:01
#    ----------------------------------- --- 182.7/198.5 MB 24.2 MB/s eta 0:00:01
#    ------------------------------------ -- 183.9/198.5 MB 23.4 MB/s eta 0:00:01
#    ------------------------------------ -- 185.0/198.5 MB 22.6 MB/s eta 0:00:01
#    ------------------------------------ -- 185.0/198.5 MB 22.6 MB/s eta 0:00:01
#    ------------------------------------ -- 185.8/198.5 MB 19.3 MB/s eta 0:00:01
#    ------------------------------------ -- 187.0/198.5 MB 19.2 MB/s eta 0:00:01
#    ------------------------------------ -- 188.0/198.5 MB 18.7 MB/s eta 0:00:01
#    ------------------------------------- - 189.2/198.5 MB 18.7 MB/s eta 0:00:01
#    ------------------------------------- - 190.4/198.5 MB 18.7 MB/s eta 0:00:01
#    ------------------------------------- - 191.7/198.5 MB 21.1 MB/s eta 0:00:01
#    ------------------------------------- - 192.8/198.5 MB 21.1 MB/s eta 0:00:01
#    --------------------------------------  194.1/198.5 MB 21.1 MB/s eta 0:00:01
#    --------------------------------------  194.8/198.5 MB 20.5 MB/s eta 0:00:01
#    --------------------------------------  194.8/198.5 MB 20.5 MB/s eta 0:00:01
#    --------------------------------------  195.5/198.5 MB 21.1 MB/s eta 0:00:01
#    --------------------------------------  195.5/198.5 MB 21.1 MB/s eta 0:00:01
#    --------------------------------------  195.7/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  196.7/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  197.8/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    --------------------------------------  198.5/198.5 MB 16.8 MB/s eta 0:00:01
#    ---------------------------------------- 198.5/198.5 MB 3.8 MB/s eta 0:00:00
# Installing collected packages: torch
#   Attempting uninstall: torch
#     Found existing installation: torch 2.2.1
#     Uninstalling torch-2.2.1:
#       Successfully uninstalled torch-2.2.1
# Successfully installed torch-2.2.0
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\peter\AppData\Roaming\Python\Python312\site-packages\~orch'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.17.1 requires torch==2.2.1, but you have torch 2.2.0 which is incompatible.
# torchaudio 2.2.1 requires torch==2.2.1, but you have torch 2.2.0 which is incompatible.
# ^C
# ^C
# ^C
# ^C
# ^C
# ^C
# ^C

# %%
import torch
import cv2
import easyocr
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image, ImageDraw, ImageFont, ImageEnhance
import sys
from spellchecker import SpellChecker
from hanspell import spell_checker
import wordninja

def text_detection(img_path):
    print("2-1 이미지 내 텍스트 인식을 진행 중입니다.")
    # easyocr Reader 생성 (한국어 인식을 위해 'ko' 설정)
    reader = easyocr.Reader(['en','ko'], gpu=False)

    # 이미지 읽기
    img = cv2.imread(img_path)
    height, width, _ = img.shape

    # 페이지를 나누기 위해 이미지의 중간 지점을 계산
    mid_point = width // 2

    # 왼쪽과 오른쪽 페이지 이미지로 나누기
    left_page = img[:, :mid_point]
    right_page = img[:, mid_point:]

    # 텍스트를 저장할 리스트 초기화
    recognized_texts = []

    # 왼쪽 페이지에서 텍스트 인식 및 바운드 박스 그리기
    result_left = reader.readtext(left_page, detail=1)
    for (bbox, text, prob) in result_left:
        # 인식된 텍스트를 리스트에 추가
        if text != 'logi' and text != 'log':
            recognized_texts.append(text)
        # 바운드 박스 좌표 추출 및 그리기
        (top_left, top_right, bottom_right, bottom_left) = bbox
        top_left = (int(top_left[0]), int(top_left[1]))
        bottom_right = (int(bottom_right[0]), int(bottom_right[1]))
        cv2.rectangle(left_page, top_left, bottom_right, (0, 255, 0), 2)
        
        # 이미지에 텍스트와 신뢰도 그리기 (PIL 사용)
        img_pil = Image.fromarray(left_page)
        draw = ImageDraw.Draw(img_pil)
        font = ImageFont.truetype("fonts/gulim.ttc", 10)
        text_to_display = f"{text} [{prob:.2f}]"
        draw.text((top_left[0], top_left[1] - 30), text_to_display, font=font, fill=(255,0,0))
        left_page = np.array(img_pil)

    # 오른쪽 페이지에서 텍스트 인식 및 바운드 박스 그리기
    result_right = reader.readtext(right_page, detail=1)
    for (bbox, text, prob) in result_right:
        # 인식된 텍스트를 리스트에 추가
        if text != 'logi' and text != 'log':
            recognized_texts.append(text)
        # 바운드 박스 좌표 추출 및 그리기
        (top_left, top_right, bottom_right, bottom_left) = bbox
        top_left = (int(top_left[0]), int(top_left[1]))
        bottom_right = (int(bottom_right[0]), int(bottom_right[1]))
        cv2.rectangle(right_page, top_left, bottom_right, (0, 255, 0), 2)
        
        # 이미지에 텍스트와 신뢰도 그리기 (PIL 사용)
        img_pil = Image.fromarray(right_page)
        draw = ImageDraw.Draw(img_pil)
        font = ImageFont.truetype("fonts/gulim.ttc", 10)
        text_to_display = f"{text} [{prob:.2f}]"
        draw.text((top_left[0], top_left[1] - 30), text_to_display, font=font, fill=(255,0,0))
        right_page = np.array(img_pil)

    # 왼쪽과 오른쪽 페이지를 하나의 이미지로 합치기
    combined_img = np.hstack((left_page, right_page))

    print("2-2 이미지 내 텍스트 인식을 완료했습니다.")
    
    # 이미지 저장 및 표시
    modified_img_path = img_path.replace(".jpg", "_labeled.jpg")  # 수정된 이미지 저장 경로
    cv2.imwrite(modified_img_path, combined_img)
    plt.figure(figsize=(10, 10))
    plt.imshow(cv2.cvtColor(combined_img, cv2.COLOR_BGR2RGB))
    plt.title("Image with Bounding Boxes")
    plt.axis('off')
    plt.show()
    print("2-3 이미지 내 텍스트 라벨링 및 저장을 완료했습니다.")

    return recognized_texts, modified_img_path
    
def text_correction(texts):
    # wordninja와 SpellChecker를 이용한 띄어쓰기 및 철자 교정 함수
    print("2-4 텍스트 철자 및 문법 교정을 진행 중입니다. ")

    
    # text가 한글인지 검사
    def is_korean(text):
        for char in text:
            if '\uac00' <= char <= '\ud7a3':
                return True
        return False

    # text가 영어인지 검사
    def is_english(text):
        try:
            text.encode(encoding='utf-8').decode('ascii')
        except UnicodeDecodeError:
            return False
        else:
            return True

    # text가 영어와 한글이 섞여 있는지 검사
    def is_mixed(text):
        return is_english(text) and is_korean(text)
    
    def correct_text(text):
        if is_english(text):
            words = wordninja.split(text)
            spell = SpellChecker()
            corrected_words = [spell.correction(word) for word in words]
            return ' '.join(corrected_words)
        elif is_korean(text):
            print("한글은 아직 정의되지 않았습니다.")
            return text
        elif is_mixed(text):
            return ''
        else:
            print("지원하지 않는 언어입니다.")
            return text
            
    # 입력 데이터가 리스트인 경우
    if isinstance(texts, list):
        corrected_texts = [correct_text(text) for text in texts]
        print("2-5 철자 및 문법 교정을 완료했습니다.")
        return corrected_texts
        
    # 입력 데이터가 문자열인 경우
    elif isinstance(texts, str):
        print("2-5 철자 및 문법 교정을 완료했습니다.")
        return correct_text(texts)
    else:
        raise ValueError("[Error] 입력 데이터는 문자열 또는 리스트여야 합니다.")
# Out:
# KeyboardInterrupt
#
# ERROR: Ignored the following yanked versions: 0.1.6, 0.1.7, 0.1.8, 0.1.9, 0.2.0, 0.2.1, 0.2.2, 0.2.2.post2, 0.2.2.post3
# ERROR: Could not find a version that satisfies the requirement torchvision==0.14.0 (from versions: 0.17.0, 0.17.1, 0.17.2, 0.18.0, 0.18.1, 0.19.0, 0.19.1, 0.20.0, 0.20.1)
# ERROR: No matching distribution found for torchvision==0.14.0
