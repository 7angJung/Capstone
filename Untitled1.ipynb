# %%
# !pip install easyocr
# !pip install opencv-python
# !pip install imutils
# Out:
# Requirement already satisfied: easyocr in c:\users\peter\appdata\roaming\python\python312\site-packages (1.7.1)
# Requirement already satisfied: torch in c:\users\peter\appdata\roaming\python\python312\site-packages (from easyocr) (2.2.1)
# Requirement already satisfied: torchvision>=0.5 in c:\users\peter\appdata\roaming\python\python312\site-packages (from easyocr) (0.17.1)
# Requirement already satisfied: opencv-python-headless in c:\users\peter\appdata\roaming\python\python312\site-packages (from easyocr) (4.9.0.80)
# Requirement already satisfied: scipy in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from easyocr) (1.12.0)
# Requirement already satisfied: numpy in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from easyocr) (1.26.4)
# Requirement already satisfied: Pillow in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from easyocr) (10.2.0)
# Requirement already satisfied: scikit-image in c:\users\peter\appdata\roaming\python\python312\site-packages (from easyocr) (0.22.0)
# Requirement already satisfied: python-bidi in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from easyocr) (0.4.2)
# Requirement already satisfied: PyYAML in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from easyocr) (6.0.1)
# Requirement already satisfied: Shapely in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from easyocr) (2.0.3)
# Requirement already satisfied: pyclipper in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from easyocr) (1.3.0.post5)
# Requirement already satisfied: ninja in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from easyocr) (1.11.1.1)
# Requirement already satisfied: filelock in c:\users\peter\appdata\roaming\python\python312\site-packages (from torch->easyocr) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from torch->easyocr) (4.9.0)
# Requirement already satisfied: sympy in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from torch->easyocr) (1.12)
# Requirement already satisfied: networkx in c:\users\peter\appdata\roaming\python\python312\site-packages (from torch->easyocr) (3.2.1)
# Requirement already satisfied: jinja2 in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from torch->easyocr) (3.1.3)
# Requirement already satisfied: fsspec in c:\users\peter\appdata\roaming\python\python312\site-packages (from torch->easyocr) (2024.3.1)
# Requirement already satisfied: six in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: imageio>=2.27 in c:\users\peter\appdata\roaming\python\python312\site-packages (from scikit-image->easyocr) (2.34.0)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from scikit-image->easyocr) (2024.2.12)
# Requirement already satisfied: packaging>=21 in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from scikit-image->easyocr) (23.2)
# Requirement already satisfied: lazy_loader>=0.3 in c:\users\peter\appdata\roaming\python\python312\site-packages (from scikit-image->easyocr) (0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from jinja2->torch->easyocr) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from sympy->torch->easyocr) (1.3.0)
# Requirement already satisfied: opencv-python in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\peter\anaconda3\envs\capstone\lib\site-packages (from opencv-python) (1.26.4)
# Collecting imutils
#   Downloading imutils-0.5.4.tar.gz (17 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: imutils
#   Building wheel for imutils (setup.py): started
#   Building wheel for imutils (setup.py): finished with status 'done'
#   Created wheel for imutils: filename=imutils-0.5.4-py3-none-any.whl size=25855 sha256=1973e0e71b367c3047a9e698980da622e2d77d50b7d3ecc3eb2aeeb6ba2bc930
#   Stored in directory: c:\users\peter\appdata\local\pip\cache\wheels\5b\76\96\ad0c321506837bef578cf3008df3916c23018435a355d9f6b1
# Successfully built imutils
# Installing collected packages: imutils
# Successfully installed imutils-0.5.4

# %%
from matplotlib import pyplot as plt
from imutils.perspective import four_point_transform
from imutils.contours import sort_contours
import imutils
from easyocr import Reader
import cv2
import requests
import numpy as np
from PIL import ImageFont, ImageDraw, Image

# %%
def plt_imshow(title='image', img=None, figsize=(8 ,5)):
    plt.figure(figsize=figsize)
 
    if type(img) == list:
        if type(title) == list:
            titles = title
        else:
            titles = []
 
            for i in range(len(img)):
                titles.append(title)
 
        for i in range(len(img)):
            if len(img[i].shape) <= 2:
                rgbImg = cv2.cvtColor(img[i], cv2.COLOR_GRAY2RGB)
            else:
                rgbImg = cv2.cvtColor(img[i], cv2.COLOR_BGR2RGB)
 
            plt.subplot(1, len(img), i + 1), plt.imshow(rgbImg)
            plt.title(titles[i])
            plt.xticks([]), plt.yticks([])
 
        plt.show()
    else:
        if len(img.shape) < 3:
            rgbImg = cv2.cvtColor(img, cv2.COLOR_GRAY2RGB)
        else:
            rgbImg = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
 
        plt.imshow(rgbImg)
        plt.title(title)
        plt.xticks([]), plt.yticks([])
        plt.show()
 
 
def make_scan_image(image, width, ksize=(5,5), min_threshold=75, max_threshold=200):
  image_list_title = []
  image_list = []
 
  image = imutils.resize(image, width=width)
  ratio = org_image.shape[1] / float(image.shape[1])
 
  # 이미지를 grayscale로 변환하고 blur를 적용
  # 모서리를 찾기위한 이미지 연산
  gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  blurred = cv2.GaussianBlur(gray, ksize, 0)
  edged = cv2.Canny(blurred, min_threshold, max_threshold)
 
  image_list_title = ['gray', 'blurred', 'edged']
  image_list = [gray, blurred, edged]
 
  # contours를 찾아 크기순으로 정렬
  cnts = cv2.findContours(edged.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
  cnts = imutils.grab_contours(cnts)
  cnts = sorted(cnts, key=cv2.contourArea, reverse=True)
 
  findCnt = None
 
  # 정렬된 contours를 반복문으로 수행하며 4개의 꼭지점을 갖는 도형을 검출
  for c in cnts:
    peri = cv2.arcLength(c, True)
    approx = cv2.approxPolyDP(c, 0.02 * peri, True)
 
    # contours가 크기순으로 정렬되어 있기때문에 제일 첫번째 사각형을 영역으로 판단하고 break
    if len(approx) == 4:
      findCnt = approx
      break
 
 
  # 만약 추출한 윤곽이 없을 경우 오류
  if findCnt is None:
    raise Exception(("Could not find outline."))
 
 
  output = image.copy()
  cv2.drawContours(output, [findCnt], -1, (0, 255, 0), 2)
  
  image_list_title.append("Outline")
  image_list.append(output)
 
  # 원본 이미지에 찾은 윤곽을 기준으로 이미지를 보정
  transform_image = four_point_transform(org_image, findCnt.reshape(4, 2) * ratio)
 
  plt_imshow(image_list_title, image_list)
  plt_imshow("Transform", transform_image)
 
  return transform_image

def putText(cv_img, text, x, y, color=(0, 0, 0), font_size=22):
  # Colab이 아닌 Local에서 수행 시에는 gulim.ttc 를 사용하면 됩니다.
  # font = ImageFont.truetype("fonts/gulim.ttc", font_size)
  font = ImageFont.truetype('/usr/share/fonts/truetype/nanum/NanumGothicBold.ttf', font_size)
  img = Image.fromarray(cv_img)
   
  draw = ImageDraw.Draw(img)
  draw.text((x, y), text, font=font, fill=color)
 
  cv_img = np.array(img)
  
  return cv_img

# %%
url = 'https://user-images.githubusercontent.com/69428232/155486780-55525c3c-8f5f-4313-8590-dd69d4ce4111.jpg'
 
image_nparray = np.asarray(bytearray(requests.get(url).content), dtype=np.uint8)
org_image = cv2.imdecode(image_nparray, cv2.IMREAD_COLOR) 
plt_imshow("orignal image", org_image)
 
business_card_image = make_scan_image(org_image, width=200, ksize=(5, 5), min_threshold=20, max_threshold=100)

# %%
langs = ['ko', 'en']
 
print("[INFO] OCR'ing input image...")
reader = Reader(lang_list=langs, gpu=False)
results = reader.readtext(business_card_image, detail=0)
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# [INFO] OCR'ing input image...

# %%
results
# Out:
# ['김 운 웅',
#  '수석',
#  'T Biz. Digital그룹 | C8C',
#  'SK',
#  'SK 주식회사',
#  '13486, 경기도 성남시 분당구 판교로 255번길 38',
#  'SK 주식회사 판교캠퍼스',
#  'Tel',
#  'Mobile',
#  'WWWskcokr']

# %%
simple_results = reader.readtext(business_card_image, detail = 0)
simple_results
# Out:
# ['김 운 웅',
#  '수석',
#  'T Biz. Digital그룹 | C8C',
#  'SK',
#  'SK 주식회사',
#  '13486, 경기도 성남시 분당구 판교로 255번길 38',
#  'SK 주식회사 판교캠퍼스',
#  'Tel',
#  'Mobile',
#  'WWWskcokr']

# %%
# loop over the results
for (bbox, text, prob) in results:
  print("[INFO] {:.4f}: {}".format(prob, text))
  
  (tl, tr, br, bl) = bbox
  tl = (int(tl[0]), int(tl[1]))
  tr = (int(tr[0]), int(tr[1]))
  br = (int(br[0]), int(br[1]))
  bl = (int(bl[0]), int(bl[1]))
 
	# 추출한 영역에 사각형을 그리고 인식한 글자를 표기합니다.
  cv2.rectangle(business_card_image, tl, br, (0, 255, 0), 2)
  business_card_image = putText(business_card_image, text, tl[0], tl[1] - 60, (0, 255, 0), 50)
	# cv2.putText(business_card_image, text, (tl[0], tl[1] - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 255, 0), 2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 # loop over the results
# ----> 2 for (bbox, text, prob) in results:
#       3   print("[INFO] {:.4f}: {}".format(prob, text))
#       5   (tl, tr, br, bl) = bbox
#
# ValueError: too many values to unpack (expected 3)

# %%
plt_imshow("Image", business_card_image, figsize=(16,10))

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import ImageFont, ImageDraw, Image
import imutils

def four_point_transform(image, pts):
    # 변환할 사각형의 4개 점을 정렬하고 변환 후의 사각형의 크기를 계산
    rect = np.array(pts)
    (tl, tr, br, bl) = rect
    widthA = np.sqrt(((br[0] - bl[0]) ** 2) + ((br[1] - bl[1]) ** 2))
    widthB = np.sqrt(((tr[0] - tl[0]) ** 2) + ((tr[1] - tl[1]) ** 2))
    maxWidth = max(int(widthA), int(widthB))
    heightA = np.sqrt(((tr[0] - br[0]) ** 2) + ((tr[1] - br[1]) ** 2))
    heightB = np.sqrt(((tl[0] - bl[0]) ** 2) + ((tl[1] - bl[1]) ** 2))
    maxHeight = max(int(heightA), int(heightB))

    # 변환 후 4개 점의 위치
    dst = np.array([
        [0, 0],
        [maxWidth - 1, 0],
        [maxWidth - 1, maxHeight - 1],
        [0, maxHeight - 1]], dtype = "float32")

    # 변환 행렬을 계산하고 적용
    M = cv2.getPerspectiveTransform(rect, dst)
    warped = cv2.warpPerspective(image, M, (maxWidth, maxHeight))

    return warped

# 여기에 이미지 경로를 넣으세요
image_path = 'capstone/onePage/test4_right.jpg'
org_image = cv2.imread(image_path)

# 이미지가 정상적으로 로드되었는지 확인
if org_image is None:
    print("이미지를 불러오는데 실패했습니다. 경로를 확인해주세요.")
else:
    # 이미지 너비. 원하는 크기로 조정하세요.
    width = 500
    # 스캔 이미지 생성
    scanned_image = make_scan_image(org_image, width)

    # 스캔된 이미지에 텍스트 추가
    result_image = putText(scanned_image, "스캔 완료!", 10, 30, color=(0, 255, 0), font_size=22)

    # 결과 이미지 표시
    plt_imshow("Result Image", result_image)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[17], line 42
#      40 width = 500
#      41 # 스캔 이미지 생성
# ---> 42 scanned_image = make_scan_image(org_image, width)
#      44 # 스캔된 이미지에 텍스트 추가
#      45 result_image = putText(scanned_image, "스캔 완료!", 10, 30, color=(0, 255, 0), font_size=22)
#
# Cell In[5], line 82, in make_scan_image(image, width, ksize, min_threshold, max_threshold)
#      79 image_list.append(output)
#      81 # 원본 이미지에 찾은 윤곽을 기준으로 이미지를 보정
# ---> 82 transform_image = four_point_transform(org_image, findCnt.reshape(4, 2) * ratio)
#      84 plt_imshow(image_list_title, image_list)
#      85 plt_imshow("Transform", transform_image)
#
# Cell In[17], line 26, in four_point_transform(image, pts)
#      19 dst = np.array([
#      20     [0, 0],
#      21     [maxWidth - 1, 0],
#      22     [maxWidth - 1, maxHeight - 1],
#      23     [0, maxHeight - 1]], dtype = "float32")
#      25 # 변환 행렬을 계산하고 적용
# ---> 26 M = cv2.getPerspectiveTransform(rect, dst)
#      27 warped = cv2.warpPerspective(image, M, (maxWidth, maxHeight))
#      29 return warped
#
# error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\imgwarp.cpp:3547: error: (-215:Assertion failed) src.checkVector(2, CV_32F) == 4 && dst.checkVector(2, CV_32F) == 4 in function 'cv::getPerspectiveTransform'
